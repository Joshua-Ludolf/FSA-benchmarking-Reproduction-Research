# %% [markdown]
# # Joshua Ludolf, Yesmin Hernandez-Reyna, Matthew Trevino
# ## CSCI 4406 - Computer Networks
# ### MileStone 1
# ## **This project aims to explore and benchmark various machine learning models to detect disks at high risk of experiencing fail-slow anomalies.**

# %% [markdown]
# ---
#
# ### First Part: Preparing Our Chameleon Server
#
# This step includes:
#
# 1. **Create Lease**
#    Reserve resources on the Chameleon cloud.
#
# 2. **Launch the Server**
#    Start the server instance using the reserved resources.
#
# 3. **Associate Floating IP**
#    Assign a public IP address to the server to enable external access.
#
# 4. **Connect to the Instance**
#    Use SSH to access the server.
#
# ---

# %% [markdown]
# ## Configuration

# %%
# %pip install python-chi
# %pip install tensorflow

import chi

chi.use_site("CHI@UC")

chi.set("project_name", "CHI-210889")

print(f'Using Project {chi.get("project_name")}')
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Collecting python-chi
#   Using cached python_chi-1.0.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting fabric (from python-chi)
#   Using cached fabric-3.2.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting keystoneauth1 (from python-chi)
#   Using cached keystoneauth1-5.8.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting openstacksdk (from python-chi)
#   Using cached openstacksdk-4.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting paramiko (from python-chi)
#   Using cached paramiko-3.5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting python-cinderclient (from python-chi)
#   Using cached python_cinderclient-9.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting python-glanceclient (from python-chi)
#   Using cached python_glanceclient-4.7.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting python-ironicclient (from python-chi)
#   Using cached python_ironicclient-5.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting python-manilaclient (from python-chi)
#   Using cached python_manilaclient-5.0.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting python-neutronclient (from python-chi)
#   Using cached python_neutronclient-11.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting python-novaclient (from python-chi)
#   Using cached python_novaclient-18.7.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting python-swiftclient (from python-chi)
#   Using cached python_swiftclient-4.6.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting python-zunclient (from python-chi)
#   Using cached python_zunclient-5.1.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: ipython in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-chi) (8.28.0)
# Collecting ipywidgets (from python-chi)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting networkx (from python-chi)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting matplotlib (from python-chi)
#   Using cached matplotlib-3.9.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting invoke>=2.0 (from fabric->python-chi)
#   Using cached invoke-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: decorator>=5 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from fabric->python-chi) (5.1.1)
# Collecting deprecated>=1.2 (from fabric->python-chi)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting bcrypt>=3.2 (from paramiko->python-chi)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting cryptography>=3.3 (from paramiko->python-chi)
#   Using cached cryptography-43.0.3-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting pynacl>=1.5 (from paramiko->python-chi)
#   Using cached PyNaCl-1.5.0-cp36-abi3-win_amd64.whl.metadata (8.7 kB)
# Requirement already satisfied: jedi>=0.16 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (5.14.3)
# Requirement already satisfied: colorama in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython->python-chi) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipywidgets->python-chi) (0.2.2)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->python-chi)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->python-chi)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting iso8601>=0.1.11 (from keystoneauth1->python-chi)
#   Using cached iso8601-2.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting os-service-types>=1.2.0 (from keystoneauth1->python-chi)
#   Using cached os_service_types-1.7.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pbr>=2.0.0 (from keystoneauth1->python-chi)
#   Using cached pbr-6.1.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting requests>=2.14.2 (from keystoneauth1->python-chi)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting stevedore>=1.20.0 (from keystoneauth1->python-chi)
#   Using cached stevedore-5.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->python-chi)
#   Using cached contourpy-1.3.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->python-chi)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->python-chi)
#   Using cached fonttools-4.54.1-cp313-cp313-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->python-chi)
#   Using cached kiwisolver-1.4.7-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib->python-chi) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib->python-chi) (24.1)
# Collecting pillow>=8 (from matplotlib->python-chi)
#   Using cached pillow-11.0.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->python-chi)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib->python-chi) (2.9.0.post0)
# Collecting PyYAML>=3.13 (from openstacksdk->python-chi)
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting dogpile.cache>=0.6.5 (from openstacksdk->python-chi)
#   Using cached dogpile.cache-1.3.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting jmespath>=0.9.0 (from openstacksdk->python-chi)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting jsonpatch!=1.20,>=1.16 (from openstacksdk->python-chi)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting netifaces>=0.10.4 (from openstacksdk->python-chi)
#   Using cached netifaces-0.11.0.tar.gz (30 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=3 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openstacksdk->python-chi) (4.3.6)
# Collecting requestsexceptions>=1.2.0 (from openstacksdk->python-chi)
#   Using cached requestsexceptions-1.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting PrettyTable>=0.7.2 (from python-cinderclient->python-chi)
#   Using cached prettytable-3.11.0-py3-none-any.whl.metadata (30 kB)
# Collecting oslo.i18n>=5.0.1 (from python-cinderclient->python-chi)
#   Using cached oslo.i18n-6.4.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting oslo.utils>=4.8.0 (from python-cinderclient->python-chi)
#   Using cached oslo.utils-7.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyOpenSSL>=17.1.0 (from python-glanceclient->python-chi)
#   Using cached pyOpenSSL-24.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting warlock>=1.2.0 (from python-glanceclient->python-chi)
#   Using cached warlock-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting wrapt>=1.7.0 (from python-glanceclient->python-chi)
#   Using cached wrapt-1.16.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting cliff>=2.8.0 (from python-ironicclient->python-chi)
#   Using cached cliff-4.7.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=3.2.0 (from python-ironicclient->python-chi)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting osc-lib>=2.0.0 (from python-ironicclient->python-chi)
#   Using cached osc_lib-3.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting Babel>=2.5.0 (from python-manilaclient->python-chi)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting debtcollector>=1.2.0 (from python-manilaclient->python-chi)
#   Using cached debtcollector-3.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting oslo.config>=5.2.0 (from python-manilaclient->python-chi)
#   Using cached oslo.config-9.6.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting oslo.log>=3.36.0 (from python-manilaclient->python-chi)
#   Using cached oslo.log-6.1.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting oslo.serialization>=2.20.0 (from python-manilaclient->python-chi)
#   Using cached oslo.serialization-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-keystoneclient>=3.8.0 (from python-manilaclient->python-chi)
#   Using cached python_keystoneclient-5.5.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting netaddr>=0.7.18 (from python-neutronclient->python-chi)
#   Using cached netaddr-1.3.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting os-client-config>=1.28.0 (from python-neutronclient->python-chi)
#   Using cached os_client_config-2.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting docker>=2.4.2 (from python-zunclient->python-chi)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting python-openstackclient>=3.12.0 (from python-zunclient->python-chi)
#   Using cached python_openstackclient-7.2.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting websocket-client>=0.44.0 (from python-zunclient->python-chi)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting autopage>=0.4.0 (from cliff>=2.8.0->python-ironicclient->python-chi)
#   Using cached autopage-0.5.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting cmd2>=1.0.0 (from cliff>=2.8.0->python-ironicclient->python-chi)
#   Using cached cmd2-2.4.3-py3-none-any.whl.metadata (12 kB)
# Collecting cffi>=1.12 (from cryptography>=3.3->paramiko->python-chi)
#   Using cached cffi-1.17.1-cp313-cp313-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from docker>=2.4.2->python-zunclient->python-chi) (308)
# Collecting urllib3>=1.26.0 (from docker>=2.4.2->python-zunclient->python-chi)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jedi>=0.16->ipython->python-chi) (0.8.4)
# Collecting jsonpointer>=1.9 (from jsonpatch!=1.20,>=1.16->openstacksdk->python-chi)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.2.0->python-ironicclient->python-chi)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.2.0->python-ironicclient->python-chi)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.2.0->python-ironicclient->python-chi)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.2.0->python-ironicclient->python-chi)
#   Using cached rpds_py-0.20.0-cp313-none-win_amd64.whl.metadata (4.2 kB)
# Collecting rfc3986>=1.2.0 (from oslo.config>=5.2.0->python-manilaclient->python-chi)
#   Using cached rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting oslo.context>=2.21.0 (from oslo.log>=3.36.0->python-manilaclient->python-chi)
#   Using cached oslo.context-5.6.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting msgpack>=0.5.2 (from oslo.serialization>=2.20.0->python-manilaclient->python-chi)
#   Using cached msgpack-1.1.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Collecting tzdata>=2022.4 (from oslo.serialization>=2.20.0->python-manilaclient->python-chi)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wcwidth in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from PrettyTable>=0.7.2->python-cinderclient->python-chi) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib->python-chi) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.14.2->keystoneauth1->python-chi)
#   Using cached charset_normalizer-3.4.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.14.2->keystoneauth1->python-chi)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.14.2->keystoneauth1->python-chi)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack-data->ipython->python-chi) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack-data->ipython->python-chi) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\joshu\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack-data->ipython->python-chi) (0.2.3)
# Collecting pycparser (from cffi>=1.12->cryptography>=3.3->paramiko->python-chi)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting pyperclip>=1.6 (from cmd2>=1.0.0->cliff>=2.8.0->python-ironicclient->python-chi)
#   Using cached pyperclip-1.9.0.tar.gz (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyreadline3 (from cmd2>=1.0.0->cliff>=2.8.0->python-ironicclient->python-chi)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Using cached python_chi-1.0.1-py3-none-any.whl (57 kB)
# Using cached fabric-3.2.2-py3-none-any.whl (59 kB)
# Using cached paramiko-3.5.0-py3-none-any.whl (227 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached keystoneauth1-5.8.0-py3-none-any.whl (325 kB)
# Using cached matplotlib-3.9.2-cp313-cp313-win_amd64.whl (7.8 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached openstacksdk-4.1.0-py3-none-any.whl (1.7 MB)
# Using cached python_cinderclient-9.6.0-py3-none-any.whl (256 kB)
# Using cached python_glanceclient-4.7.0-py3-none-any.whl (206 kB)
# Using cached python_ironicclient-5.8.0-py3-none-any.whl (264 kB)
# Using cached python_manilaclient-5.0.0-py3-none-any.whl (516 kB)
# Using cached python_neutronclient-11.3.1-py3-none-any.whl (295 kB)
# Using cached python_novaclient-18.7.0-py3-none-any.whl (336 kB)
# Using cached python_swiftclient-4.6.0-py3-none-any.whl (88 kB)
# Using cached python_zunclient-5.1.0-py3-none-any.whl (155 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached cliff-4.7.0-py3-none-any.whl (81 kB)
# Using cached contourpy-1.3.0-cp313-cp313-win_amd64.whl (218 kB)
# Using cached cryptography-43.0.3-cp39-abi3-win_amd64.whl (3.1 MB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached debtcollector-3.0.0-py3-none-any.whl (23 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached dogpile.cache-1.3.3-py3-none-any.whl (58 kB)
# Using cached fonttools-4.54.1-cp313-cp313-win_amd64.whl (2.2 MB)
# Using cached invoke-2.2.0-py3-none-any.whl (160 kB)
# Using cached iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached kiwisolver-1.4.7-cp313-cp313-win_amd64.whl (55 kB)
# Using cached netaddr-1.3.0-py3-none-any.whl (2.3 MB)
# Using cached os_client_config-2.1.0-py3-none-any.whl (31 kB)
# Using cached os_service_types-1.7.0-py2.py3-none-any.whl (24 kB)
# Using cached osc_lib-3.1.0-py3-none-any.whl (89 kB)
# Using cached oslo.config-9.6.0-py3-none-any.whl (132 kB)
# Using cached oslo.i18n-6.4.0-py3-none-any.whl (46 kB)
# Using cached oslo.log-6.1.2-py3-none-any.whl (74 kB)
# Using cached oslo.serialization-5.5.0-py3-none-any.whl (26 kB)
# Using cached oslo.utils-7.3.0-py3-none-any.whl (129 kB)
# Using cached pbr-6.1.0-py2.py3-none-any.whl (108 kB)
# Using cached pillow-11.0.0-cp313-cp313-win_amd64.whl (2.6 MB)
# Using cached prettytable-3.11.0-py3-none-any.whl (28 kB)
# Using cached PyNaCl-1.5.0-cp36-abi3-win_amd64.whl (212 kB)
# Using cached pyOpenSSL-24.2.1-py3-none-any.whl (58 kB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached python_keystoneclient-5.5.0-py3-none-any.whl (397 kB)
# Using cached python_openstackclient-7.2.0-py3-none-any.whl (1.1 MB)
# Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached requestsexceptions-1.4.0-py2.py3-none-any.whl (3.8 kB)
# Using cached stevedore-5.3.0-py3-none-any.whl (49 kB)
# Using cached warlock-2.0.1-py3-none-any.whl (9.8 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached wrapt-1.16.0-py3-none-any.whl (23 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached autopage-0.5.2-py3-none-any.whl (30 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached cffi-1.17.1-cp313-cp313-win_amd64.whl (182 kB)
# Using cached charset_normalizer-3.4.0-cp313-cp313-win_amd64.whl (102 kB)
# Using cached cmd2-2.4.3-py3-none-any.whl (147 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached msgpack-1.1.0-cp313-cp313-win_amd64.whl (75 kB)
# Using cached oslo.context-5.6.0-py3-none-any.whl (20 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Using cached rpds_py-0.20.0-cp313-none-win_amd64.whl (214 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: netifaces, pyperclip
#   Building wheel for netifaces (pyproject.toml): started
#   Building wheel for netifaces (pyproject.toml): finished with status 'error'
#   Building wheel for pyperclip (pyproject.toml): started
#   Building wheel for pyperclip (pyproject.toml): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11018 sha256=2087598307dc8ef34c34272c4d9100f13807789962a66f6b28a9ea8ff7f205d6
#   Stored in directory: c:\users\joshu\appdata\local\pip\cache\wheels\9c\79\90\c9e831caaffa2633ad99f1d35c6ea39866b92de62e909e89ef
# Successfully built pyperclip
# Failed to build netifaces
#   error: subprocess-exited-with-error
#
#   × Building wheel for netifaces (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'netifaces' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for netifaces
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (netifaces)
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 get_ipython().run_line_magic('pip', 'install python-chi')
#       2 get_ipython().run_line_magic('pip', 'install tensorflow')
# ----> 4 import chi
#       6 chi.use_site("CHI@UC")
#       8 chi.set("project_name", "CHI-210889")
#
# ModuleNotFoundError: No module named 'chi'

# %% [markdown]
# ## Create Lease

# %%
import os
import keystoneauth1, blazarclient
from chi import lease

reservations = []
lease_node_type = "compute_cascadelake_r"

try:
    print("Creating lease...")
    lease.add_fip_reservation(reservations, count=1)
    lease.add_node_reservation(reservations, node_type=lease_node_type, count=1)

    start_date, end_date = lease.lease_duration(hours=3)

    l = lease.create_lease(
        f"{os.getenv('USER')}-benchmark", 
        reservations, 
        start_date=start_date, 
        end_date=end_date
    )
    lease_id = l["id"]

    print("Waiting for lease to start ...")
    lease.wait_for_active(lease_id)
    print("Lease is now active!")
except keystoneauth1.exceptions.http.Unauthorized as e:
    print("Unauthorized.\nDid set your project name and and run the code in the first cell?")
except blazarclient.exception.BlazarClientException as e:
    print(f"There is an issue making the reservation. Check the calendar to make sure a {lease_node_type} node is available.")
    print("https://chi.uc.chameleoncloud.org/project/leases/calendar/host/")
    print(e)
except Exception as e:
    print("An unexpected error happened.")
    print(e)
# Out:
# Creating lease...
# error: not enough resources available with query {'resource_type': 'physical:host', 'resource_properties': '["==", "$node_type", "compute_cascadelake_r"]', 'hypervisor_properties': '', 'min': 1, 'max': 1, 'start_date': datetime.datetime(2024, 10, 23, 17, 47), 'end_date': datetime.datetime(2024, 10, 24, 20, 46), 'project_id': 'd14a518d45cf494eb37b2de09a791a23', 'count_range': '1-1', 'before_end': 'default', 'on_start': 'default'}
# An unexpected error happened.
# 'NoneType' object is not subscriptable

# %% [markdown]
# ## Provision Node

# %%
from chi import server
import os
import threading

image = "CC-Ubuntu20.04"

# Function to wait for server to be active
def wait_for_server_active(server_id):
    print("Waiting for server to start ...")
    server.wait_for_active(server_id)
    print("Done")

# Create server
s = server.create_server(
    f"{os.getenv('USER')}-benchmark",
    image_name=image,
    reservation_id=lease.get_node_reservation(lease_id)
)

# Start a thread to wait for the server to be active
wait_thread = threading.Thread(target=wait_for_server_active, args=(s.id,))
wait_thread.start()

# Continue with other initializations if needed

# Wait for the server to be active before proceeding
wait_thread.join()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_627/1741732520.py in <cell line: 14>()
#      15     f"{os.getenv('USER')}-benchmark",
#      16     image_name=image,
# ---> 17     reservation_id=lease.get_node_reservation(lease_id)
#      18 )
#      19
#
# NameError: name 'lease_id' is not defined

# %% [markdown]
# ## Associate Floating-IP

# %%
import time
import socket

floating_ip = lease.get_reserved_floating_ips(lease_id)[0]
server.associate_floating_ip(s.id, floating_ip_address=floating_ip)
print(f"Waiting for SSH connectivity on {floating_ip} ...")

# Timeout in seconds
timeout = 60 * 2
interval = 10  # Interval to wait between retries
start_time = time.perf_counter()

while True:
    try:
        with socket.create_connection((floating_ip, 22), timeout=10):  # Shorter connection timeout for each try
            print("Connection successful")
            break
    except (OSError, socket.timeout) as ex:
        if time.perf_counter() - start_time >= timeout:
            print(f"After {timeout} seconds, could not connect via SSH. Please try again.")
            break
        print("Retrying connection...")
        time.sleep(interval)

# %% [markdown]
# ## Configure Instance

# %%
from chi import ssh

with ssh.Remote(floating_ip) as conn:
    # test
    conn.run("ls")

# %% [markdown]
# ---
#
# ### Second Part: Preparing the Environment and Data for the Experiments
#
# This step includes:
#
# 1. **Download Data from the Repository**
#    Retrieve the data from my repository, noting there are two clusters from 25-cluster Perseus.
#
# 2. **Upload All Necessary Files to the Server**
#    Transfer the experiment scripts, datasets, and any other required files to the server.
#
# 3. **Uncompress the Necessary Datasets**
#    Extract the datasets to the appropriate directories for use in the experiments.
#
# 4. **Install the Dependencies**
#    Install all required libraries and tools, typically using package managers like `pip` for Python libraries.
#
# ---
# ### Note
#
# Due to the memory limitations of Trovi, they had only provided data for two clusters from the Perseus dataset. If you are interested in the performance of all clusters, please refer to the provided repository. Their repository includes comprehensive test results and heatmaps.
#
# - The **scripts** directory contains all the source code for the algorithms.
# - The **index** directory contains index files that map each script to its respective cluster data.
# - The **requirements.txt** file lists all the dependencies needed for the project.
#
# ---

# %% [markdown]
# ## Preparing the Experiment

# %%
# !git clone https://github.com/songxikang/data.git

# %%
with ssh.Remote(floating_ip) as conn:
    # Create data, index, and scripts directories
    conn.run("mkdir -p data")
    conn.run("mkdir -p index")
    conn.run("mkdir -p scripts")
    
    # Upload Perseus to the data directory
    conn.put("data/cluster_A.tar.gz", "data/cluster_A.tar.gz")
    conn.put("data/cluster_B.tar.gz", "data/cluster_B.tar.gz")
    conn.put("index/slow_drive_info.csv", "data/slow_drive_info.csv")
    
    # Suppress the output of the following commands
    conn.run("tar -xvzf data/cluster_A.tar.gz -C data > /dev/null 2>&1 && rm data/cluster_A.tar.gz > /dev/null 2>&1")
    conn.run("tar -xvzf data/cluster_B.tar.gz -C data > /dev/null 2>&1 && rm data/cluster_B.tar.gz > /dev/null 2>&1")
    
    # Upload our FSA
    conn.put("scripts/csr.py", "scripts/csr.py")
    conn.put("scripts/multi_pred.py", "scripts/multi_pred.py")
    conn.put("scripts/lstm.py", "scripts/lstm.py")
    conn.put("scripts/patchTST.py", "scripts/patchTST.py")
    conn.put("scripts/xgboost.py", "scripts/xgboost.py")
    
    # Upload index files
    conn.put("index/A_index.csv", "index/A_index.csv")
    conn.put("index/B_index.csv", "index/B_index.csv")
    conn.put("index/all_drive_info.csv", "index/all_drive_info.csv")
    
    # Install dependancies
    conn.put("requirements.txt")
    conn.sudo("apt-get install -y python3-pip")
    conn.run("pip install -r requirements.txt")

# %% [markdown]
# ---
#
# ### Third Part: Running the Experiments
#
# This step includes:
#
# 1. **Upload the `run_experiments.sh` Script**
#    - Transfer the `run_experiments.sh` script to the server.
#
# 2. **Run the `run_experiments.sh` Script**
#    - Execute the script to run all the FSA (Fail-Slow Anomaly Detection) algorithms.
#    - The script will generate the prediction results.
#
# 3. **Compress the Output**
#    - The script will compress the output directory into `output.tar.gz`.
#
# 4. **Download the Results**
#    - Download the `output.tar.gz` file to obtain the prediction results to our local directory.
#
# ---

# %%
with ssh.Remote(floating_ip) as conn:
    # Upload the script
    conn.put("run_experiments.sh")
    # Run the script 
    conn.run("bash run_experiments.sh")

# %%
import tarfile

with ssh.Remote(floating_ip) as conn:
    # Download the output
    conn.get("output.tar.gz")
with tarfile.open("output.tar.gz") as tar:
    # Extract the results to our notebook
    tar.extractall()
print("done")

# %% [markdown]
# #### Fourth Part: Parsing the Results
#
# This step includes:
#
# 1. **Parse the Results in the Output Directory**
#    - Uncompress the `output.tar.gz` file to access the results. ( done in previous step)
#
# 2. **Analyze the Results**
#    - Open the `result_parser.ipynb` notebook to see all the analysis.
#    - The notebook contains detailed analysis and visualizations of the prediction results.
